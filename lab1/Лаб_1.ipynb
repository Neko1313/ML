# %% [markdown]
# <a href="https://colab.research.google.com/github/Neko1313/ML/blob/main/lab1/%D0%9B%D0%B0%D0%B1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Что то интересное

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/loan_approval_dataset.csv")

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
df[:5]
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df[-5:]
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
# ...

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %% [markdown]
# Какие средние значения в каждой числовой колонке вашего датасета?

# %%
df.mean()
# Out:
# <ipython-input-9-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# loan_id                      2.135000e+03
#  no_of_dependents            2.498712e+00
#  income_annum                5.059124e+06
#  loan_amount                 1.513345e+07
#  loan_term                   1.090045e+01
#  cibil_score                 5.999361e+02
#  residential_assets_value    7.472617e+06
#  commercial_assets_value     4.973155e+06
#  luxury_assets_value         1.512631e+07
#  bank_asset_value            4.976692e+06
# dtype: float64

# %% [markdown]
# #Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# ##MIN

# %%
df.min()
# Out:
# loan_id                              1
#  no_of_dependents                    0
#  education                    Graduate
#  self_employed                      No
#  income_annum                   200000
#  loan_amount                    300000
#  loan_term                           2
#  cibil_score                       300
#  residential_assets_value      -100000
#  commercial_assets_value             0
#  luxury_assets_value            300000
#  bank_asset_value                    0
#  loan_status                  Approved
# dtype: object

# %% [markdown]
# ##MAX

# %%
df.max()
# Out:
# loan_id                               4269
#  no_of_dependents                        5
#  education                    Not Graduate
#  self_employed                         Yes
#  income_annum                      9900000
#  loan_amount                      39500000
#  loan_term                              20
#  cibil_score                           900
#  residential_assets_value         29100000
#  commercial_assets_value          19400000
#  luxury_assets_value              39200000
#  bank_asset_value                 14700000
#  loan_status                      Rejected
# dtype: object

# %% [markdown]
# #Типизация

# %%
df.dtypes
# Out:
# loan_id                       int64
#  no_of_dependents             int64
#  education                   object
#  self_employed               object
#  income_annum                 int64
#  loan_amount                  int64
#  loan_term                    int64
#  cibil_score                  int64
#  residential_assets_value     int64
#  commercial_assets_value      int64
#  luxury_assets_value          int64
#  bank_asset_value             int64
#  loan_status                 object
# dtype: object

# %% [markdown]
# #Фильтрация

# %%
df_filter_loan_term = df[df[" loan_term"] > 19]
df_filter_loan_term
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 2           3                  3       Graduate             No        9100000
# 4           5                  5   Not Graduate            Yes        9800000
# 7           8                  2       Graduate            Yes        5700000
# 8           9                  0       Graduate            Yes         800000
# 25         26                  5   Not Graduate             No        3100000
# ...       ...                ...            ...            ...            ...
# 4219     4220                  4       Graduate            Yes        5600000
# 4232     4233                  1       Graduate            Yes         200000
# 4244     4245                  3   Not Graduate             No        1800000
# 4262     4263                  5       Graduate             No        1300000
# 4265     4266                  0   Not Graduate            Yes        3300000
#
# ...

# %%
df_filter_luxury_assets_value = df[df[" luxury_assets_value"] < 1_000_000]
df_filter_luxury_assets_value
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 95         96                  5       Graduate             No         300000
# 101       102                  2   Not Graduate            Yes         300000
# 110       111                  0   Not Graduate             No         300000
# 125       126                  3       Graduate             No         200000
# 126       127                  4   Not Graduate            Yes         400000
# ...       ...                ...            ...            ...            ...
# 4009     4010                  4   Not Graduate             No         200000
# 4182     4183                  1   Not Graduate             No         400000
# 4212     4213                  0   Not Graduate             No         200000
# 4217     4218                  5   Not Graduate            Yes         400000
# 4232     4233                  1       Graduate            Yes         200000
#
# ...

# %%
df_filter_no_of_dependents = df[df[" no_of_dependents"] == 0]
df_filter_no_of_dependents
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 1           2                  0   Not Graduate            Yes        4100000
# 5           6                  0       Graduate            Yes        4800000
# 8           9                  0       Graduate            Yes         800000
# 23         24                  0   Not Graduate            Yes         500000
# 24         25                  0   Not Graduate             No        4900000
# ...       ...                ...            ...            ...            ...
# 4251     4252                  0       Graduate            Yes        6100000
# 4254     4255                  0   Not Graduate            Yes        8900000
# 4257     4258                  0       Graduate             No        9700000
# 4259     4260                  0   Not Graduate            Yes        4500000
# 4265     4266                  0   Not Graduate            Yes        3300000
#
# ...

# %%
df.groupby([" self_employed"]).mean()
# Out:
# <ipython-input-30-5d259aa7a705>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby([" self_employed"]).mean()
#                     loan_id   no_of_dependents   income_annum   loan_amount  \
#  self_employed
#  No             2132.833412           2.497404   5.052430e+06  1.512025e+07
#  Yes            2137.135349           2.500000   5.065721e+06  1.514647e+07
#
#                  loan_term   cibil_score   residential_assets_value  \
#  self_employed
#  No              10.876829    600.781029               7.432374e+06
#  Yes             10.923721    599.103256               7.512279e+06
#
#                  commercial_assets_value   luxury_assets_value  \
#  self_employed
#  No                         5.052714e+06          1.508584e+07
# ...
